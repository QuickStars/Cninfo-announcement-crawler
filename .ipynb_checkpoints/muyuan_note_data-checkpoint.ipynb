# %%
import pdfplumber
import os
import re
import pandas as pd
import sys
import datetime
import calendar
from tqdm import tqdm
import win32com
import win32com.client
import docx

# %%
dirPath = os.getcwd()+'\\announcements\\muyuan\\notes\\'
fileList = os.listdir(dirPath)

# %%
def doc2docx(path):
    w = win32com.client.Dispatch('Word.Application')
    w.Visible = 0
    w.DisplayAlerts = 0
    doc = w.Documents.Open(path)
    newpath = os.path.splitext(path)[0] + '.docx'
    doc.SaveAs(newpath, 12, False, "", True, "", False, False, False, False)
    doc.Close()
    w.Quit()
    os.remove(path)
    return newpath

# %%
# change all doc to docx
for file in tqdm(fileList):
    if file[-3:] == 'DOC':
        doc2docx(dirPath+file)
fileList = os.listdir(dirPath)
# Out:
# 100%|██████████| 100/100 [00:00<?, ?it/s]

# %%
def to_dateTime(dateText):
    dateData = re.findall('(.*?)年(.*?)月(.*?)日',dateText)[0]
    dateTime = datetime.datetime(int(dateData[0]), int(dateData[1]), int(dateData[2]))
    return dateTime

# %%
def get_noteData(fullText, noteDate):
    fullText = '\n'+fullText
    noteData = []
    qsData=[]
    for text in re.split('\n(.*?？)\n',fullText)[1:]:
        if re.match('.*?？$',text):
            qsData = [noteDate,text]
        else:
            qsData.append(text)
            noteData.append(qsData)
    return noteData

# %%
def read_note_docx(filePath, threshold=100):
    doc = docx.Document(filePath)
    tables = doc.tables
    table = tables[1]

    fullText = ''
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cellText = table.cell(i,j).text 
            if(len(cellText)>threshold):
                noteText = cellText
            date = re.match('\d+年\d+月\d+日$',cellText)
            if date:
                noteDate = to_dateTime(date.group())

    get_noteData(noteText, noteDate)

    return noteData

# %%
def read_note_pdf(filePath):
    with pdfplumber.open(filePath) as pdf:
        fullText = ''
        for pageNum in range(len(pdf.pages)):
            fullText = fullText + pdf.pages[pageNum].extract_text()
        noteDate = to_dateTime(re.findall('日期(.*?)$',fullText,re.S)[0].replace(' ',''))
        noteText = re.findall('人员姓名.*?\n(.*?？.*?)附件清单',fullText,re.S)[0]
        
        get_noteData(noteText, noteDate)
        
        return noteData

# %%
def read_note(filePath):
    if 'doc' in filePath[-10:].lower():
        return read_note_docx(filePath)
    elif 'pdf'in filePath[-10:].lower():
        return read_note_pdf(filePath)
    else:
        print('File type error: Should be either docx or pdf.')
        return []

# %%
noteData = []
for file in tqdm(fileList):
    filePath = dirPath + file
    try:
        noteData = noteData + read_note(filePath)
    except:
        print(filePath)
# Out:
#   9%|▉         | 9/100 [00:00<00:03, 27.30it/s]
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\1201304623.docx
#  49%|████▉     | 49/100 [00:01<00:01, 40.95it/s]
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\63595217.docx
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\63791201.docx
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\63866429.docx
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\64000941.docx
#  55%|█████▌    | 55/100 [00:13<00:35,  1.28it/s]
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\牧原股份：002714牧原股份业绩说明会、路演活动信息20210512.PDF
#  56%|█████▌    | 56/100 [00:21<00:57,  1.30s/it]
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\牧原股份：002714牧原股份业绩说明会、路演活动信息20220512.PDF
#  86%|████████▌ | 86/100 [00:38<00:11,  1.24it/s]
# C:\Users\admin\Projects\Cninfo accouncement crawler\announcements\muyuan\notes\牧原股份：002714牧原股份调研活动信息20220530.PDF
# 100%|██████████| 100/100 [00:45<00:00,  2.18it/s]

# %%
tag = ['date', 'question', 'answer']
noteDf = pd.DataFrame(noteData, columns=tag)
noteDf.set_index('date', inplace = True)
noteDf.sort_index(inplace=True)

# %%
    filePath = dirPath + '64000941.docx'
    doc = docx.Document(filePath)
    tables = doc.tables
    table = tables[1]

    fullText = ''
    for i in range(len(table.rows)):
        for j in range(len(table.columns)):
            cellText = table.cell(i,j).text 
            print(cellText)
# Out:
# 投资者关系活动类别
# √ 特定对象调研       □分析师会议
# □媒体采访            □业绩说明会
# □新闻发布会          □路演活动
# □现场参观
# □其他 （请文字说明其他活动内容）
# √ 特定对象调研       □分析师会议
# □媒体采访            □业绩说明会
# □新闻发布会          □路演活动
# □现场参观
# □其他 （请文字说明其他活动内容）
# 参与单位名称及人员姓名
# 海通证券夏木、中航证券薄晓旭、国信证券赵钦、国都证券张小强
# 海通证券夏木、中航证券薄晓旭、国信证券赵钦、国都证券张小强
# 时间
# 2014年5月7日上午11:00 - 12:00
# 2014年5月7日上午11:00 - 12:00
# 地点
# 公司会议室
# 公司会议室
# 上市公司接待人员姓名
# 公司董事长、总经理秦英林先生，董事、副总经理曹治年先生，董事会秘书、副总经理张春武先生，副总经理苏党林先生，财务总监张明波先生等。
# 公司董事长、总经理秦英林先生，董事、副总经理曹治年先生，董事会秘书、副总经理张春武先生，副总经理苏党林先生，财务总监张明波先生等。
# 会谈内容
# 会谈内容
# 会谈内容
# 一、公司不断扩大规模，未来发展的最终方向？
# 1、养猪行业空间大，行业的利润趋于合理。随着行业的发展，公司将来可能会进入食品层面，但持谨慎的态度。
# 2、根据美国、欧洲的经验，大型食品、农牧企业往往都覆盖了较长的产业链，很少依赖某一个环节盈利。
# 3、对于产业链延伸的问题，目前公司仅仅处于思考、探讨的阶段，没有具体规划安排。
#
# 二、公司2014年成本有所上涨，影响公司成本的因素有哪几方面？
# 养殖成本总体是逐步上升趋势，主要由以下几方面影响因素：
# 1、饲料因素。玉米的价格高于小麦价格的时候，采用小麦的成本优势较明显。小麦价格高于玉米价格时，根据公司的营养配方，可能采用小麦还具有成本优势，但当小麦价格高出玉米价格超过临界点时，将采用玉米作为配方原粮。公司对库存做合理管理，按月作库存。根据小麦和玉米的价格比调整饲料配方，保持最低饲料成本。公司目前采用玉米作为配方原粮，但将持续关注小麦。
# 2、生产管理因素。生产管理是看不见的成本，例如猪舍内小环境的控制，如果猪舍内冷，会导致猪腹泻，死亡率高，料肉比降低等。猪舍内热也会影响到生猪的生长。饲养管理是看不见的因素，但会直接影响到公司的成本。
# 3、猪舍设计的因素。公司的猪舍自行设计，能够根据生猪的生长设计适合的猪舍，猪舍建设成本低，出栏每头猪摊销的费用就低。
# 4、技术因素。使用技术能够整合更低价格的原料。机械化、种猪繁育、疫病防控等方面的技术因素结合在一起，会使得公司整体的饲养成本低于同行业。
#
# 三、公司商品猪出栏体重是否有变化？
# 1、与2013年相比，公司整体平均出栏体重没有明显变化。
# 2、前期猪价低的时候，部分养殖户出现压栏现象。公司不存在这种情况，“大规模一体化养殖”是流水线作业，分阶段饲养意味着必须保持猪舍的正常流转，无法压栏。
# 3、公司可以根据猪价的情况，适当调整出栏体重。
#
# 四、如何看待近两天猪价的快速上涨？
# 1、生猪市场非常分散，单个企业无法影响市场价格。
# 2、公司不对短期市场进行预测，市场因素具有不可把握性，。
# 3、近两天猪价上涨快，主要是沿海省份，广东、浙江、山东等地涨幅大。但目前市场上没有特别缺生猪，前期猪价低的时候冻肉库存也增加较多。从供需层面看，无法说明近两天猪肉价格的快速上涨。
#
# 五、公司未来产能建设规划。
# 1、内乡地区产能基本确定，邓州子公司将重点建设募投项目，钟祥牧原一期项目在建，曹县牧原养殖场在建，唐河牧原子公司养殖场在建，扶沟牧原子公司目前饲料厂在建。
# 2、养殖场从动工到投产需要2年，养猪的生产周期长，在建的养殖场形成出栏的时间不确定。
#
# 六、公司2014年的出栏规模
# 1、公司2014年计划出栏生猪150-200万头，根据市场行情的变化调整营养配方，可以一定程度上调整出栏量。
# 2、4月份销售生猪18万头左右，一般前半年的出栏量小于后半年的出栏量。
#
# 七、公司的育种优势
# 1、公司育种体系主要针对两个目标，一方面是根据市场需求改善猪肉品质，另一方面是提高生产成绩。2002年，公司自己调整育种方向后第一批商品猪出栏；2010年以来，市场给了公司自己育种商品猪的较好的反应。
# 2、公司坚持育种，坚持做安全食品。公司做的不是猪，是肉，是食品，最终对食品的认可，才是对公司养猪的认可。
#
# 一、公司不断扩大规模，未来发展的最终方向？
# 1、养猪行业空间大，行业的利润趋于合理。随着行业的发展，公司将来可能会进入食品层面，但持谨慎的态度。
# 2、根据美国、欧洲的经验，大型食品、农牧企业往往都覆盖了较长的产业链，很少依赖某一个环节盈利。
# 3、对于产业链延伸的问题，目前公司仅仅处于思考、探讨的阶段，没有具体规划安排。
#
# 二、公司2014年成本有所上涨，影响公司成本的因素有哪几方面？
# 养殖成本总体是逐步上升趋势，主要由以下几方面影响因素：
# 1、饲料因素。玉米的价格高于小麦价格的时候，采用小麦的成本优势较明显。小麦价格高于玉米价格时，根据公司的营养配方，可能采用小麦还具有成本优势，但当小麦价格高出玉米价格超过临界点时，将采用玉米作为配方原粮。公司对库存做合理管理，按月作库存。根据小麦和玉米的价格比调整饲料配方，保持最低饲料成本。公司目前采用玉米作为配方原粮，但将持续关注小麦。
# 2、生产管理因素。生产管理是看不见的成本，例如猪舍内小环境的控制，如果猪舍内冷，会导致猪腹泻，死亡率高，料肉比降低等。猪舍内热也会影响到生猪的生长。饲养管理是看不见的因素，但会直接影响到公司的成本。
# 3、猪舍设计的因素。公司的猪舍自行设计，能够根据生猪的生长设计适合的猪舍，猪舍建设成本低，出栏每头猪摊销的费用就低。
# 4、技术因素。使用技术能够整合更低价格的原料。机械化、种猪繁育、疫病防控等方面的技术因素结合在一起，会使得公司整体的饲养成本低于同行业。
#
# 三、公司商品猪出栏体重是否有变化？
# 1、与2013年相比，公司整体平均出栏体重没有明显变化。
# 2、前期猪价低的时候，部分养殖户出现压栏现象。公司不存在这种情况，“大规模一体化养殖”是流水线作业，分阶段饲养意味着必须保持猪舍的正常流转，无法压栏。
# 3、公司可以根据猪价的情况，适当调整出栏体重。
#
# 四、如何看待近两天猪价的快速上涨？
# 1、生猪市场非常分散，单个企业无法影响市场价格。
# 2、公司不对短期市场进行预测，市场因素具有不可把握性，。
# 3、近两天猪价上涨快，主要是沿海省份，广东、浙江、山东等地涨幅大。但目前市场上没有特别缺生猪，前期猪价低的时候冻肉库存也增加较多。从供需层面看，无法说明近两天猪肉价格的快速上涨。
#
# 五、公司未来产能建设规划。
# 1、内乡地区产能基本确定，邓州子公司将重点建设募投项目，钟祥牧原一期项目在建，曹县牧原养殖场在建，唐河牧原子公司养殖场在建，扶沟牧原子公司目前饲料厂在建。
# 2、养殖场从动工到投产需要2年，养猪的生产周期长，在建的养殖场形成出栏的时间不确定。
#
# 六、公司2014年的出栏规模
# 1、公司2014年计划出栏生猪150-200万头，根据市场行情的变化调整营养配方，可以一定程度上调整出栏量。
# 2、4月份销售生猪18万头左右，一般前半年的出栏量小于后半年的出栏量。
#
# 七、公司的育种优势
# 1、公司育种体系主要针对两个目标，一方面是根据市场需求改善猪肉品质，另一方面是提高生产成绩。2002年，公司自己调整育种方向后第一批商品猪出栏；2010年以来，市场给了公司自己育种商品猪的较好的反应。
# 2、公司坚持育种，坚持做安全食品。公司做的不是猪，是肉，是食品，最终对食品的认可，才是对公司养猪的认可。
#
# 一、公司不断扩大规模，未来发展的最终方向？
# 1、养猪行业空间大，行业的利润趋于合理。随着行业的发展，公司将来可能会进入食品层面，但持谨慎的态度。
# 2、根据美国、欧洲的经验，大型食品、农牧企业往往都覆盖了较长的产业链，很少依赖某一个环节盈利。
# 3、对于产业链延伸的问题，目前公司仅仅处于思考、探讨的阶段，没有具体规划安排。
#
# 二、公司2014年成本有所上涨，影响公司成本的因素有哪几方面？
# 养殖成本总体是逐步上升趋势，主要由以下几方面影响因素：
# 1、饲料因素。玉米的价格高于小麦价格的时候，采用小麦的成本优势较明显。小麦价格高于玉米价格时，根据公司的营养配方，可能采用小麦还具有成本优势，但当小麦价格高出玉米价格超过临界点时，将采用玉米作为配方原粮。公司对库存做合理管理，按月作库存。根据小麦和玉米的价格比调整饲料配方，保持最低饲料成本。公司目前采用玉米作为配方原粮，但将持续关注小麦。
# 2、生产管理因素。生产管理是看不见的成本，例如猪舍内小环境的控制，如果猪舍内冷，会导致猪腹泻，死亡率高，料肉比降低等。猪舍内热也会影响到生猪的生长。饲养管理是看不见的因素，但会直接影响到公司的成本。
# 3、猪舍设计的因素。公司的猪舍自行设计，能够根据生猪的生长设计适合的猪舍，猪舍建设成本低，出栏每头猪摊销的费用就低。
# 4、技术因素。使用技术能够整合更低价格的原料。机械化、种猪繁育、疫病防控等方面的技术因素结合在一起，会使得公司整体的饲养成本低于同行业。
#
# 三、公司商品猪出栏体重是否有变化？
# 1、与2013年相比，公司整体平均出栏体重没有明显变化。
# 2、前期猪价低的时候，部分养殖户出现压栏现象。公司不存在这种情况，“大规模一体化养殖”是流水线作业，分阶段饲养意味着必须保持猪舍的正常流转，无法压栏。
# 3、公司可以根据猪价的情况，适当调整出栏体重。
#
# 四、如何看待近两天猪价的快速上涨？
# 1、生猪市场非常分散，单个企业无法影响市场价格。
# 2、公司不对短期市场进行预测，市场因素具有不可把握性，。
# 3、近两天猪价上涨快，主要是沿海省份，广东、浙江、山东等地涨幅大。但目前市场上没有特别缺生猪，前期猪价低的时候冻肉库存也增加较多。从供需层面看，无法说明近两天猪肉价格的快速上涨。
#
# 五、公司未来产能建设规划。
# 1、内乡地区产能基本确定，邓州子公司将重点建设募投项目，钟祥牧原一期项目在建，曹县牧原养殖场在建，唐河牧原子公司养殖场在建，扶沟牧原子公司目前饲料厂在建。
# 2、养殖场从动工到投产需要2年，养猪的生产周期长，在建的养殖场形成出栏的时间不确定。
#
# 六、公司2014年的出栏规模
# 1、公司2014年计划出栏生猪150-200万头，根据市场行情的变化调整营养配方，可以一定程度上调整出栏量。
# 2、4月份销售生猪18万头左右，一般前半年的出栏量小于后半年的出栏量。
#
# 七、公司的育种优势
# 1、公司育种体系主要针对两个目标，一方面是根据市场需求改善猪肉品质，另一方面是提高生产成绩。2002年，公司自己调整育种方向后第一批商品猪出栏；2010年以来，市场给了公司自己育种商品猪的较好的反应。
# 2、公司坚持育种，坚持做安全食品。公司做的不是猪，是肉，是食品，最终对食品的认可，才是对公司养猪的认可。
#
# 附件清单（如有）
# 附件清单（如有）
#
# 日期
# 日期
# 2014.5.7

# %%
filePath = dirPath + '牧原股份：002714牧原股份调研活动信息20220530.PDF'

with pdfplumber.open(filePath) as pdf:
    fullText = ''
    for pageNum in range(len(pdf.pages)):
        fullText = fullText + pdf.pages[pageNum].extract_text()

    fullText
    noteText = re.findall('人员姓名.*?\n(.*?？.*?)',fullText,re.S)[0]
    noteText

# %%
fullText
# Out:
# '证券代码：002714 证券简称：牧原股份\n牧原食品股份有限公司\n投资者关系活动记录表\n编号：2021-03\n投资者关系活动类别 □特定对象调研□分析师会议\n□媒体采访√业绩说明会\n□新闻发布会□路演活动\n□现场参观\n□其他\n参与单位名称及人员姓名 参与公司2020年度网上业绩说明会的投资者\n时间 2021年05 月11日下午15:00-17:00\n地点 全景网“投资者关系互动平台”（http://ir.p5w.net）\n公司董事长、总裁秦英林先生\n公司副董事长、常务副总裁、财务负责人曹治年先生\n上市公司接待人员姓名 公司董事会秘书、首席战略官（CSO）秦军先生\n独立董事刘利剑先生\n保荐代表人张燚先生\n会谈主要内容\n为与广大投资者充分沟通交流，公司于2021 年5月11日（星期二）下午15：00-17：\n00在全景网举办了2020年度业绩说明会。本次业绩说明会采用网络远程方式举行，主要\n交流内容见附件。\n附件清单（如有） 《牧原股份2020年度网上业绩说明会交流要点》\n日期 2021年05 月12日附件：\n牧原股份2020年度网上业绩说明会交流要点\n序号 提问内容 回复内容\n您好，公司的发展战略包含以下几方面：1、食品安全战略：公司持续完善“全自\n养、全链条、智能化”的经营模式，通过建立严密的食品安全管理体系，加强食品\n安全管理，为社会提供安全、健康的猪肉产品。2、科学育种战略：公司通过科学\n化的育种技术，提高种猪的遗传性能，改善猪肉的品质和口感，降低饲养成本，\n提升养殖效率。公司通过进一步扩大核心种猪群规模，保持了在国内生猪育种领\n域的领先地位，为公司不断扩大商品猪的饲养规模奠定基础。3、“全自养、全链\n条、智能化”战略：“全自养、全链条、智能化”经营模式可以实现集约化生产经营，\n并且可以利用资金、技术、人才等优势，快速提高养殖规模与养殖效率，有效把\n控食品安全。为顺应畜牧业规模化养殖的趋势，公司将继续实施全自养、全链条、\n智能化的战略，进一步扩大饲料加工、种猪选育、种猪扩繁、商品猪饲养、屠宰\n1 猪周期震荡下行，公司未来战略可否阐述一下\n肉食等生产环节经营规模，不断提高猪肉品质与食品安全标准，让更多人吃上高\n品质猪肉。4、标准化生产战略：公司通